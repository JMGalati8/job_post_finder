# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import datetime
import pandas as pd
import numpy as np
import psycopg2
from psycopg2 import OperationalError
import json
import re
import config

# %%
job_types = {
    'normal':{"data-automation": "normalJob"},
    'sponsored':{"data-automation": "premiumJob"}
}

attributes ={
    'job_name': {'data-automation': 'jobTitle'},
    'company': {'data-automation': 'jobCompany'},
    'location': {'data-automation': 'jobLocation'},
    'pay': {'data-automation': 'jobSalary'},
    'category': {'data-automation': 'jobClassification'},
    'sub_category': {'data-automation': 'jobSubClassification'},
    'job_link': {'data-automation': 'jobSubClassification'}
}

daterange=2

# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import datetime
import config
import pandas as pd
import numpy as np
import psycopg2
from psycopg2 import OperationalError
import json
import re

def sleeper(min_second=0.2, max_second=2):
    """

    :param min_second: minimum seconds
    :param max_second: maximum seconds
    :return: sleep for random period between min and max seconds

    :note: Need to update this to have proper handling for the seconds
    """
    multiplier = 10
    min_time = min_second * multiplier
    max_time = max_second * multiplier
    time.sleep(random.randint(min_time, max_time) / multiplier)


def db_connection():
    with open('../1. Admin/db_data.json') as json_data:
        db_data = json.load(json_data)
        conn = create_connection(
            db_data['db_name'], db_data['db_user'], db_data['db_password'], db_data['db_host'], db_data['db_port']
        )

    return conn


def job_info_handler(job_soup):
    """
    :param job_soup: The html of the jobs - This is a list of the html for each job. Each entry is one job.
    :return: Return a list of jobs in dictionaries. Details of the jobs are contained in the dictionaries.
    """
    job_output = []
    for j in job_soup:

    #Create the dictionary that gets output for each job. Specific handling for each item is in the config file.
        job_info = {
            'job_type': '',
            "job_name": "",
            "company": "",
            "location": "",
            "pay": "",
            "category": "",
            'sub_category': '',
            "first_seen": datetime.datetime.now(),
            "job_link": "",
            "site_id": ""
        }

        for k, v in config.attributes.items():
            var = j.find(attrs=v)
            if var:
                job_info[k] = var.getText()

            # This is terrible, look for a solution
            job_info['job_link'] = j.find(attrs={'data-automation': 'jobTitle'})['href']
            job_info['site_id'] = re.search('(\d+)', job_info['job_link']).group(0)

        job_output.append(job_info)

    return job_output


def search_site(site_link):
    """
    :param site_link: The site link that is to be searched - Currently just a an entry in config, will need to consider how to develop further.
    :return: Returns all jobs from the page after looping through all pages.
    """
    page_number = 1
    output_list = []
    start_flag = True
    while start_flag:
        link = site_link + str(page_number)
        page = requests.get(link)
        html_soup = BeautifulSoup(page.text, 'html.parser')
        norm_jobs = html_soup.find_all("article", {"data-automation": "normalJob"})
        prem_job = html_soup.find_all("article", {"data-automation": "premiumJob"})
        norm_jobs.extend(prem_job)

        if not norm_jobs:
            break

        output_list.extend(job_info_handler(norm_jobs))
        sleeper()
        page_number += 1

    return output_list


def remove_previous_entries(job_ad_list):
    """
    Moved this out of the 'search site' function as there were times where we were dropping all records and it was causing issues
    :param job_ad_list: List of job ads from the 'search site' function
    :return: Same list but with all entries already in db removed
    """
    existing_id = pd.read_sql_query(config.existing_id_sql, con=db_connection())['site_id'].tolist()
    job_ad_list[:] = [d for d in job_ad_list if d.get('site_id') not in existing_id]

    return job_ad_list


def search_job_ad_details(job_info_list):
    """
    :param job_info_list: Cleaned list of jobs broken into individual dictionaries
    :return: Returns the cleaned list of jobs with the job description added to each entry.
    """
    for x in job_info_list:
        base_link = 'https://www.seek.com.au'
        job_link = base_link + x['job_link']
        job_page = requests.get(job_link)
        job_page_soup = BeautifulSoup(job_page.text, 'html.parser')
        x['job_ad_details'] = job_page_soup.find(attrs={'data-automation': 'jobAdDetails'}).getText()
        sleeper()

    print('Job Details Completed')


def create_connection(db_name, db_user, db_password, db_host, db_port):
    """

    :param db_name: database name
    :param db_user: username
    :param db_password: password
    :param db_host: host location
    :param db_port: port to access
    :return: Gives us the connection to db
    """
    connection = None
    try:
        connection = psycopg2.connect(
            database=db_name,
            user=db_user,
            password=db_password,
            host=db_host,
            port=db_port,
        )
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    return connection


def execute_many(conn, df, table):
    """
    This is an insert command, so the table needs to be created already.
    :param conn: pre-created connection to db
    :param df: df to insert
    :param table: table to insert df into
    :return: insert records into a table
    """
    # Create a list of tupples from the dataframe values
    tuples = [tuple(x) for x in df.to_numpy()]
    # Comma-separated dataframe columns
    cols = ','.join(list(df.columns))
    # SQL quert to execute
    query = "INSERT INTO %s(%s) VALUES(%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s)" % (table, cols)
    cursor = conn.cursor()
    try:
        cursor.executemany(query, tuples)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_many() done")
    cursor.close()


def seek_process():
    """
    Complete seek process, scraping details and saving these into the pre-defined table
    :return: update db

    :note: Need to improve this with logging and messages. Also update the connection details to work off a json before we save to git
    """

    print('Search Site')
    results = []
    for job_classification in config.classification_search_list:
        seek_link = f'https://www.seek.com.au/{job_classification}?daterange={config.daterange}&page='
        print(job_classification)
        site_results = search_site(seek_link)
        print(len(site_results))
        results.extend(site_results)
    results = remove_previous_entries(results)
    print(f'Getting job details for {len(results)} jobs')
    search_job_ad_details(results)
    df = pd.DataFrame(results)
    df = df.replace(r'^\s*$', np.nan, regex=True)
    print(f'Writing data to db - {df.shape[0]} rows')

    with open('../1. Admin/db_data.json') as json_data:
        db_data = json.load(json_data)
        conn = create_connection(
            db_data['db_name'], db_data['db_user'], db_data['db_password'], db_data['db_host'], db_data['db_port']
        )

    execute_many(conn, df, 'jobs_details')

# %%
output_list=[]
link =  f'https://www.seek.com.au/jobs?daterange={daterange}&page=1'
page = requests.get(link)
html_soup = BeautifulSoup(page.text, 'html.parser')
norm_jobs = html_soup.find_all("article", {"data-automation": "normalJob"})
prem_job = html_soup.find_all("article", {"data-automation": "premiumJob"})
norm_jobs.extend(prem_job)

output_list.extend(job_info_handler(norm_jobs))

# %%
with open('../1. Admin/db_data.json') as json_data:
    db_data = json.load(json_data)
    conn = create_connection(
        db_data['db_name'], db_data['db_user'], db_data['db_password'], db_data['db_host'], db_data['db_port']
    )
# Out:
# Connection to PostgreSQL DB successful

# %%
existing_id=pd.read_sql_query(f'select site_id from jobs_details where first_seen >= current_date-{daterange}',con=conn)['site_id'].tolist()

# %%
existing_id
# Out:
# ['67672445',
#  '67678974',
#  '67659775',
#  '67655271',
#  '67657549',
#  '67659207',
#  '67641989',
#  '67642445',
#  '67637889',
#  '67628402',
#  '67626405',
#  '67658646',
#  '67657200',
#  '67658949',
#  '67666735',
#  '67671718',
#  '67670132',
#  '67673070',
#  '67664329',
#  '67666156',
#  '67658801',
#  '67667281',
#  '67678974',
#  '67657629',
#  '67668133',
#  '67656982',
#  '67669406',
#  '67672207',
#  '67670852',
#  '67666557',
#  '67668706',
#  '67655742',
#  '67667563',
#  '67657226',
#  '67656332',
#  '67672011',
#  '67674406',
#  '67656309',
#  '67659274',
#  '67672674',
#  '67671117',
#  '67669961',
#  '67671617',
#  '67655559',
#  '67655153',
#  '67667836',
#  '67671789',
#  '67661911',
#  '67662056',
#  '67671189',
#  '67661529',
#  '67669947',
#  '67675340',
#  '67675574',
#  '67660237',
#  '67675090',
#  '67664761',
#  '67655548',
#  '67674139',
#  '67672119',
#  '67672088',
#  '67656471',
#  '67655785',
#  '67675548',
#  '67671968',
#  '67660007',
#  '67655529',
#  '67655371',
#  '67675146',
#  '67655947',
#  '67659097',
#  '67679012',
#  '67667223',
#  '67678470',
#  '67659476',
#  '67665034',
#  '67670348',
#  '67669489',
#  '67673077',
#  '67671460',
#  '67660375',
#  '67675165',
#  '67663255',
#  '67669890',
#  '67678093',
#  '67655189',
#  '67664063',
#  ...]

# %%
for j in norm_jobs:
    for k, v in attributes.items():
        var = j.find(attrs=v)
        if var:
            k = var.getText()

# %%
re.search('(\d+)', k)

# %%
len(output_list)
# Out:
# 22

# %%
output_list[:] = [d for d in output_list if d.get('site_id') not in existing_id]

# %%
len(output_list)
# Out:
# 17

# %%
output_list
# Out:
# [{'job_type': '',
#   'job_name': 'Virtual Assistant |\xa0Work From Home |\xa0School Hours (NSW)',
#   'company': 'Offsiters',
#   'location': 'Sydney NSW',
#   'pay': '$30 – $35 per hour',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Administrative Assistants',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 935400),
#   'job_link': '/job/67697531?type=standout',
#   'site_id': '67697531'},
#  {'job_type': '',
#   'job_name': 'Virtual Assistant |\xa0Work From Home |\xa0School Hours (VIC)',
#   'company': 'Offsiters',
#   'location': 'Melbourne VIC',
#   'pay': '$30 – $35 per hour',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Administrative Assistants',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 936400),
#   'job_link': '/job/67697585?type=standout',
#   'site_id': '67697585'},
#  {'job_type': '',
#   'job_name': 'Customer Service Officer - Hybrid Work From Home',
#   'company': 'Plan Partners',
#   'location': 'Brisbane QLD',
#   'pay': '',
#   'category': '(Call Centre & Customer Service)',
#   'sub_category': 'Customer Service - Call Centre',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 937423),
#   'job_link': '/job/67689370?type=standout',
#   'site_id': '67689370'},
#  {'job_type': '',
#   'job_name': 'Customer Service Officer - Hybrid Work From Home',
#   'company': 'Plan Partners',
#   'location': 'Melbourne VIC',
#   'pay': '',
#   'category': '(Call Centre & Customer Service)',
#   'sub_category': 'Customer Service - Call Centre',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 939418),
#   'job_link': '/job/67689345?type=standout',
#   'site_id': '67689345'},
#  {'job_type': '',
#   'job_name': 'Administration Officer',
#   'company': 'Relationships Australia NSW',
#   'location': 'Macquarie Park',
#   'pay': '',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Administrative Assistants',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 941383),
#   'job_link': '/job/67701113?type=standout',
#   'site_id': '67701113'},
#  {'job_type': '',
#   'job_name': 'Receptionist/Admin Assistant (part-time or full-time position available)',
#   'company': 'Leibler Yavneh College',
#   'location': 'Elsternwick',
#   'pay': '',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Receptionists',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 942381),
#   'job_link': '/job/67694212?type=standard',
#   'site_id': '67694212'},
#  {'job_type': '',
#   'job_name': 'Student Support Officer',
#   'company': 'Strathfield College',
#   'location': 'Sydney NSW',
#   'pay': '',
#   'category': '(Education & Training)',
#   'sub_category': 'Student Services',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 943378),
#   'job_link': '/job/67689694?type=standard',
#   'site_id': '67689694'},
#  {'job_type': '',
#   'job_name': 'Student Services Officer',
#   'company': 'Strathfield College',
#   'location': 'Melbourne VIC',
#   'pay': '',
#   'category': '(Education & Training)',
#   'sub_category': 'Student Services',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 944375),
#   'job_link': '/job/67689816?type=standard',
#   'site_id': '67689816'},
#  {'job_type': '',
#   'job_name': 'WORK FROM HOME Call Centre Representatives',
#   'company': '',
#   'location': 'Logan Central',
#   'pay': '$24 – $26 per hour',
#   'category': '(Call Centre & Customer Service)',
#   'sub_category': 'Customer Service - Call Centre',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 945372),
#   'job_link': '/job/67688502?type=standout',
#   'site_id': '67688502'},
#  {'job_type': '',
#   'job_name': 'Customer Service Officer - Hybrid Work From Home',
#   'company': 'Plan Partners',
#   'location': 'Chatswood',
#   'pay': '',
#   'category': '(Call Centre & Customer Service)',
#   'sub_category': 'Customer Service - Call Centre',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 947367),
#   'job_link': '/job/67689372?type=standout',
#   'site_id': '67689372'},
#  {'job_type': '',
#   'job_name': 'headspace Receptionist',
#   'company': 'New Horizons',
#   'location': 'Chatswood',
#   'pay': '$31.07 per Hour + Super + Salary Packaging',
#   'category': '(Healthcare & Medical)',
#   'sub_category': 'Medical Administration',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 949362),
#   'job_link': '/job/67693695?type=standout',
#   'site_id': '67693695'},
#  {'job_type': '',
#   'job_name': 'Full Time and Fixed Term  Administration Support Officer - General',
#   'company': 'The GEO Group Australia Pty Ltd',
#   'location': 'Melbourne VIC',
#   'pay': '',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Administrative Assistants',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 950387),
#   'job_link': '/job/67689361?type=standout',
#   'site_id': '67689361'},
#  {'job_type': '',
#   'job_name': 'Customer Service / Administration Support',
#   'company': '',
#   'location': 'Bayside & Eastern Suburbs',
#   'pay': '$50,000 - $59,999',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Administrative Assistants',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 951384),
#   'job_link': '/job/67690731?type=standard',
#   'site_id': '67690731'},
#  {'job_type': '',
#   'job_name': 'Admissions Officer',
#   'company': 'Kaplan Business School',
#   'location': 'Brisbane QLD',
#   'pay': '$70K-$75K plus super plus great benefits',
#   'category': '(Education & Training)',
#   'sub_category': 'Student Services',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 952381),
#   'job_link': '/job/67690402?type=standout',
#   'site_id': '67690402'},
#  {'job_type': '',
#   'job_name': 'Admissions Officer',
#   'company': 'Kaplan Business School',
#   'location': 'Melbourne VIC',
#   'pay': '$70K-$75K plus super plus great benefits',
#   'category': '(Education & Training)',
#   'sub_category': 'Student Services',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 955374),
#   'job_link': '/job/67690387?type=standout',
#   'site_id': '67690387'},
#  {'job_type': '',
#   'job_name': 'Administration Assistant',
#   'company': 'The Distributor Group',
#   'location': 'Macquarie Park',
#   'pay': '$55,000 – $65,000 per year',
#   'category': '(Administration & Office Support)',
#   'sub_category': 'Client & Sales Administration',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 956373),
#   'job_link': '/job/67701632?type=promoted',
#   'site_id': '67701632'},
#  {'job_type': '',
#   'job_name': 'Managing Director',
#   'company': 'La Bella Life',
#   'location': 'Warrnambool',
#   'pay': '',
#   'category': '(CEO & General Management)',
#   'sub_category': 'COO & MD',
#   'first_seen': datetime.datetime(2023, 5, 24, 20, 46, 49, 956373),
#   'job_link': '/job/67705320?type=promoted',
#   'site_id': '67705320'}]

# %% [markdown]
# Testing Append

# %%
results = []
test_out = ['Hello', 'Yes']
results.extend(test_out)

# %%
results
# Out:
# ['Hello', 'Yes']

# %%
results = []
test_out = []
results.extend(test_out)

# %%
results = []
test_out = ['Hello', 'Yes']
results.extend(test_out)
results
# Out:
# ['Hello', 'Yes']

# %%
out = requests.get('https://www.seek.com.au/job/67729590')

# %%
out.history
# Out:
# []

# %%
r = requests.get('http://github.com/')

# %%
r.url
# Out:
# 'https://github.com/'

# %%
r.status_code
# Out:
# 200

# %%
r.history
# Out:
# [<Response [301]>]

# %%
requests.codes.ok
# Out:
# 200

# %% [markdown]
# Test Dictionary

# %%
test_dict = [{'id': 1,
             'name': 'Jack'},
            {'id': 2,
            'name': 'Alex'},
            {'broken':'Nothing'},
            {'id': 5,
            'name': 'Alex'}]

# %%
items = [1, 3, 5]

# %%
match
# Out:
# [1, 3]

# %%
for x in test_dict:
    print(x.get('id'))
# Out:
# 1
# 2
# None

# %%
tlist = [(d.get('id', 'default') for d in test_dict)]

# %%
tlist
# Out:
# [<generator object <genexpr> at 0x000002886D9990B0>]

# %%
match=[]
for i in items:
    for d in test_dict:
        if i in d.get('id', -9999):
            match.extend(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-707873b4d187> in <module>
#       2 for i in items:
#       3     for d in test_dict:
# ----> 4         if str(i) in d.get('id', -9999):
#       5             match.extend(i)
#
# TypeError: argument of type 'int' is not iterable

# %%
match=[]
for i in items:
    for d in test_dict:
        if i == d.get('id', -9999):
            match.append(i)

# %%
match
# Out:
# [1, 5]

# %%
dict_list = [x for x in ((d.get('id', -9999) for d in test_dict))]
dict_list
# Out:
# [1, 2, -9999, 5]
